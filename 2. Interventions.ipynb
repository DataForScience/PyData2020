# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>Why and What If? Causal Inference For Everyone</h1>
#         <h1>Interventions</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
from collections import Counter
from pprint import pprint

import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt 

import scipy
from scipy.special import expit

import statsmodels.formula.api as smf

from CausalModel import CausalModel

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# watermark  2.0.2
# numpy      1.19.2
# matplotlib 3.3.2
# scipy      1.5.2
# pandas     1.1.3
# Thu Nov 12 2020
#
# CPython 3.8.5
# IPython 7.19.0
#
# compiler   : Clang 10.0.0
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 7cfc0e7f13c782b4052c2b4519a9ecc938a49f46

# %% [markdown]
# Load default figure style

# %%
plt.style.use('./d4sci.mplstyle')

# %% [markdown]
# Let us consider this DAG

# %%
G = CausalModel()
G.add_causation('B', 'A')
G.add_causation('B', 'Z')
G.add_causation('C', 'Z')
G.add_causation('C', 'D')
G.add_causation('A', 'X')
G.add_causation('X', 'W')
G.add_causation('W', 'Y')
G.add_causation('D', 'Y')
G.add_causation('Z', 'X')
G.add_causation('Z', 'Y')

G.pos = {'B': (-1, 1),              'C': (1, 1),
         'A': (-1, 0), 'Z': (0, 0), 'D': (1, 0),
         'X': (-1, -1), 'W': (0, -1), 'Y': (1, -1),}

# %%
fig, ax = plt.subplots(1, figsize=(3, 2.5))
G.plot(ax=ax)

# %%
G.save_model('dags/Primer.Fig.3.8.dot')

# %% [markdown]
# ## Back-Door Criterion

# %% [markdown]
# Back-Door Criterion - A a set of variables Z satisfies the backdoor criterion relative to (X, Y) if:
# - no node in Z is a descendant of X,
# - Z blocks every path between X and Y that contains an arrow into X

# %% [markdown]
# All backdoor paths go through Z

# %%
paths = G.all_paths('X', 'Y')

# %%
fig, ax_lst = plt.subplots(2, 2, figsize=(6, 5))
ax_lst = np.array(ax_lst).flatten()

pos = 0
for i, path in enumerate(paths):
    if 'W' in path: # skip the direct path
        continue
    G.plot_path(path, ax=ax_lst[pos])
    pos += 1

ax_lst[-1].axis('off');

# %% [markdown]
# So we must condition on Z. Since Z is a collider we have to also condition on one of it's input (or their descendants), so one of (A, B, C, or D). Z in addition to any of these 4 nodes will fulfill the back-door criteria.

# %% [markdown]
# The pair ('A', 'Z') being the set of parents of X is an obvious choice.

# %%
G.parents('X')
# Out:
# ['A', 'Z']

# %% [markdown]
# ## Front-door Criterion

# %% [markdown]
# Front-Door Criterion - A set of variables Z satisfies the front door criterion relative to (X, Y) if:
# - Z intercepts all directed paths from X, to Y
# - There is no unblocked path between
# - All back-door paths from Z to Y are blocked by X

# %% [markdown]
# The only node that fulfills all three requirements is W

# %%
N = 100000
df = pd.DataFrame({
    'B': np.random.normal(0, 1, N), 
    'C': np.random.normal(0, 1, N),})

df['A'] = df['B'] + np.random.normal(0, .1, N)
df['D'] = np.random.binomial(1, expit(df['C']-1))
df['Z'] = np.random.binomial(1, expit(df['B'] + df['C']-2))
df['X'] = np.random.binomial(1, expit(df['Z'] + df['A']))
df['W'] = np.random.binomial(1, expit(-df['X']))
df['Y'] = np.random.binomial(1, expit(-df['D'] - df['W']+ 3*df['Z']))

# %%
model_orig = smf.ols('Y~X', df).fit()

# %%
model_orig.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     2493.
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):               0.00
# Time:                        17:35:28   Log-Likelihood:                -70899.
# No. Observations:              100000   AIC:                         1.418e+05
# Df Residuals:                   99998   BIC:                         1.418e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3704      0.002    163.387      0.000       0.366       0.375
# X              0.1555      0.003     49.929      0.000       0.149       0.162
# ==============================================================================
# Omnibus:                   371375.604   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15068.721
# Skew:                           0.182   Prob(JB):                         0.00
# Kurtosis:                       1.133   Cond. No.                         2.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_values = pd.DataFrame({'X': np.array([0, 1])})

# %%
model_orig.predict(X_values)
# Out:
# 0    0.370377
# 1    0.525908
# dtype: float64

# %% [markdown]
# ## Intervention

# %%
# Replace the values of X with a random number and propagate downstream
df['X'] = np.random.binomial(1, 0.5, N) 

df['W'] = np.random.binomial(1, expit(-df['X']))
df['Y'] = np.random.binomial(1, expit(-df['D'] - df['W']+ 3*df['Z']))

# %%
model_int = smf.ols('Y~X', df).fit()

# %%
model_int.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     237.2
# Date:                Thu, 12 Nov 2020   Prob (F-statistic):           1.85e-53
# Time:                        17:35:28   Log-Likelihood:                -71973.
# No. Observations:              100000   AIC:                         1.440e+05
# Df Residuals:                   99998   BIC:                         1.440e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4266      0.002    192.164      0.000       0.422       0.431
# X              0.0484      0.003     15.401      0.000       0.042       0.055
# ==============================================================================
# Omnibus:                   351232.381   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16516.785
# Skew:                           0.197   Prob(JB):                         0.00
# Kurtosis:                       1.048   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_int.predict(X_values)
# Out:
# 0    0.426602
# 1    0.475012
# dtype: float64

# %% [markdown]
# ## Average Causal Effect

# %%
P_int = model_int.predict(X_values)

# %%
P_int[1]-P_int[0]
# Out:
# 0.04840977507256233

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" align="center" border="0" width=300px>
# </div>
